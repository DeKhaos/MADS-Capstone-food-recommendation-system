# %%
# Add autoreload at the top of the notebook you're working on 
# in order for it to auto refresh when you change the 'project_package'
# %load_ext autoreload
# %autoreload 2

# %%
from project_package.data_collection import example_dataset

# %%
example_dataset.main()
# Out:
# 2026-02-08 17:39:07.476 | INFO     | project_package.data_collection.example_dataset:main:20 - Processing dataset...
# 100%|██████████| 10/10 [00:00<00:00, 2000.43it/s]
# 2026-02-08 17:39:07.484 | INFO     | project_package.data_collection.example_dataset:main:23 - Something happened for iteration 5.
# 2026-02-08 17:39:07.491 | SUCCESS  | project_package.data_collection.example_dataset:main:24 - Processing dataset complete.
