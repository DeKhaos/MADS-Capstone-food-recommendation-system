# %%
from project_package.data_collection import example_dataset

# %%
example_dataset.main()
# Out:
# 2026-02-08 10:43:54.177 | INFO     | project_package.data_collection.example_dataset:main:20 - Processing dataset...
# 100%|██████████| 10/10 [00:00<00:00, 2002.05it/s]
# 2026-02-08 10:43:54.190 | INFO     | project_package.data_collection.example_dataset:main:23 - Something happened for iteration 5.
# 2026-02-08 10:43:54.197 | SUCCESS  | project_package.data_collection.example_dataset:main:24 - Processing dataset complete.
